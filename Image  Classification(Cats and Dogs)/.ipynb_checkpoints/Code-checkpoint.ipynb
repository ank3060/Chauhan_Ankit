# %% [markdown]
# ---
# ---
# ### Necessary Imports

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
import os 

# %matplotlib inline
# %config Completer.use_jedi = False

# %% [markdown]
# ---
# ---
# ### Number of Images for train test

# %%
dogs = len(os.listdir('CATS_DOGS/train/DOG/'))
cats = len(os.listdir('CATS_DOGS/train/CAT/'))
print(f'Number of Dog Images for Training Data : {dogs} \nNumber of Cat Images for Training Data : {cats} ')
# Out:
# Number of Dog Images for Training Data : 9372
# Number of Cat Images for Training Data : 9371

# %%
dogs = len(os.listdir('CATS_DOGS/test/DOG/'))
cats = len(os.listdir('CATS_DOGS/test/CAT/'))
print(f'Number of Dog Images for Testing Data : {dogs} \nNumber of Cat Images for Testing Data : {cats} ')
# Out:
# Number of Dog Images for Testing Data : 3125
# Number of Cat Images for Testing Data : 3126

# %% [markdown]
# ---
# ---
# ### Lets see some random Images from dataset

# %%
# function to show image in RGB as opencv reads in=mage in BGR

def show(img):
    plt.figure(figsize=(3,3),dpi=150)
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
dog = cv2.imread('CATS_DOGS/train/DOG/1128.jpg')
show(dog)

# %%
cat = cv2.imread('CATS_DOGS/train/CAT/1446.jpg')
show(cat)

# %%
dog.shape
# Out:
# (368, 199, 3)

# %%
cat.shape
# Out:
# (480, 425, 3)

# %% [markdown]
# **We can see that image image is of varying shape , so we have to keep this in mind while training model**

# %% [markdown]
# ---
# ---
# ### Image Manipulation
#
# To make our model more robust we must train it on some randomly manipulated images.
# Manipulation can be done by rescaling , fliping along axis , rotating etc

# %%
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
image_gen = ImageDataGenerator(rotation_range=30,
                               width_shift_range=0.1,
                               height_shift_range=0.1,
                               rescale=1/255,
                               shear_range=0.2,
                               zoom_range=0.2,
                               horizontal_flip=True,
                               fill_mode='nearest'
                              )

# %%
show(image_gen.random_transform(dog))

# %%
show(image_gen.random_transform(dog))

# %% [markdown]
# Seems like random image manipulation is working fine

# %% [markdown]
# ---
# ---
# ### Generating Randomly manipulated image from Directary
#
# We will use flow_from_directary method of ImageDataGenerator for this
# For it to work Image data must be in a perticular structure
#
# Structure Needed:
#
# * Image Data Folder
#     * Class 1
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * Class 2
#         * 0.jpg
#         * 1.jpg
#         * ...
#     * ...
#     * Class n

# %%
image_gen.flow_from_directory('CATS_DOGS/train/')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
image_gen.flow_from_directory('CATS_DOGS/test/')
# Out:
# Found 6251 images belonging to 2 classes.

# %% [markdown]
# Seems about right

# %% [markdown]
# ### Fixing Image size
# We have seen above that all the images are of different shape, which may cause difficulty while training the model
# Hence we need to fix the image shape beforehand so that every image we be scaled accordingly before training.

# %%
# width,height,channels
image_shape = (150,150,3)

# %% [markdown]
# ---
# ---
#
# ## Creating a Model

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=(150,150,3), activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(128))
model.add(Activation('relu'))

# Randomly turn off 50% of neurons to avoid Overfitting
model.add(Dropout(0.5))

# Only 1 output neuron is required as our classification in binary
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18496)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               2367616
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 129
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,424,065
# Trainable params: 2,424,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
batch_size = 16

train_image_gen = image_gen.flow_from_directory('CATS_DOGS/train',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 18743 images belonging to 2 classes.

# %%
test_image_gen = image_gen.flow_from_directory('CATS_DOGS/test',
                                               target_size=image_shape[:2],
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 6251 images belonging to 2 classes.

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %% [markdown]
# Assigned value for classification

# %% [markdown]
# ---
# #### Since we are training our model on 18000+ images, we will get warning for some Images

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
results = model.fit_generator(train_image_gen,epochs=50,
                              steps_per_epoch=150,
                              validation_data=test_image_gen,
                             validation_steps=12)
# Out:
# Epoch 1/50
# 150/150 [==============================] - 364s 2s/step - loss: 0.6806 - acc: 0.5796 - val_loss: 0.6819 - val_acc: 0.5797
# Epoch 2/50
# 150/150 [==============================] - 362s 2s/step - loss: 0.6773 - acc: 0.5900 - val_loss: 0.6602 - val_acc: 0.5623
# Epoch 3/50
# 150/150 [==============================] - 362s 2s/step - loss: 0
50
# 150/150 [==============================] - 362s 2s/step - loss: 0.4930 - acc: 0.7586 - val_loss: 0.4912 - val_acc: 0.7565
# Epoch 32/50
# 150/150 [==============================] - 363s 2s/step - loss: 0.4811 - acc: 0.7687 - val_loss: 0.4798 - val_acc: 0.7740
# Epoch 33/50
# 150/150 [==============================] - 362s 2s/step - loss: 0.4858 - acc: 0.7554 - val_loss: 0.4662 - val_acc: 0.7757
# Epoch 34/50
# 150/150 [==============================] - 363s 2s/step - loss: 0.4805 - acc: 0.7696 - val_loss: 0.4734 - val_acc: 0.7751
# Epoch 35/50
# 150/150 [==============================] - 365s 2s/step - loss: 0.4757 - acc: 0.7621 - val_loss: 0.4819 - val_acc: 0.7658
# Epoch 36/50
# 150/150 [==============================] - 362s 2s/step - loss: 0.4621 - acc: 0.7829 - val_loss: 0.4552 - val_acc: 0.7863
# Epoch 37/50
# 150/150 [==============================] - 363s 2s/step - loss: 0.4834 - acc: 0.7696 - val_loss: 0.4777 - val_acc: 0.7788
# Epoch 38/50
# 150/150 [==============================] - 362s 2s/step - loss: 0.4680 - acc: 0.7903 - val_loss: 0.4490 - val_acc: 0.7890
# Epoch 39/50
# 150/150 [==============================] - 363s 2s/step - loss: 0.4964 - acc: 0.7579 - val_loss: 0.4577 - val_acc: 0.7941
# Epoch 40/50
# 150/150 [==============================] - 366s 2s/step - loss: 0.4580 - acc: 0.7804 - val_loss: 0.4366 - val_acc: 0.7940
# Epoch 41/50
# 150/150 [==============================] - 437s 3s/step - loss: 0.4626 - acc: 0.7879 - val_loss: 0.4585 - val_acc: 0.7772
# Epoch 42/50
# 150/150 [==============================] - 364s 2s/step - loss: 0.4728 - acc: 0.7742 - val_loss: 0.4353 - val_acc: 0.8031
# Epoch 43/50
# 150/150 [==============================] - 375s 3s/step - loss: 0.4536 - acc: 0.7863 - val_loss: 0.4413 - val_acc: 0.7968
# Epoch 44/50
# 150/150 [==============================] - 411s 3s/step - loss: 0.4492 - acc: 0.8021 - val_loss: 0.4467 - val_acc: 0.7885
# Epoch 45/50
# 150/150 [==============================] - 418s 3s/step - loss: 0.4451 - acc: 0.8004 - val_loss: 0.4321 - val_acc: 0.8000
# Epoch 46/50
# 150/150 [==============================] - 409s 3s/step - loss: 0.4562 - acc: 0.7867 - val_loss: 0.4303 - val_acc: 0.8040
# Epoch 47/50
# 150/150 [==============================] - 410s 3s/step - loss: 0.4617 - acc: 0.7821 - val_loss: 0.4458 - val_acc: 0.7946
# Epoch 48/50
# 150/150 [==============================] - 417s 3s/step - loss: 0.4418 - acc: 0.7937 - val_loss: 0.4297 - val_acc: 0.8037
# Epoch 49/50
# 150/150 [==============================] - 420s 3s/step - loss: 0.4245 - acc: 0.8050 - val_loss: 0.4330 - val_acc: 0.7983
# Epoch 50/50
# 150/150 [==============================] - 386s 3s/step - loss: 0.4449 - acc: 0.7929 - val_loss: 0.4612 - val_acc: 0.7820

# %% [markdown]
# ---
# ### Saving Model

# %%
# model.save('cats_nd_dogs_50Epoch.h5')

# %% [markdown]
# ---
# ---
#
# ### Accuracy Analysis

# %%
results.history['acc']
# Out:
# [0.5795833333333333,
#  0.59,
#  0.6039314095268984,
#  0.6054166666666667,
#  0.64125,
#  0.6370833333333333,
#  0.64625,
#  0.6791666666666667,
#  0.6908333333333333,
#  0.6954166666666667,
#  0.6920833333333334,
#  0.7183333333333334,
#  0.7041666666666667,
#  0.6995833333333333,
#  0.7047260561182827,
#  0.7195833333333334,
#  0.73375,
#  0.7308333333333333,
#  0.7308333333333333,
#  0.72125,
#  0.7366666666666667,
#  0.7386030949642847,
#  0.725,
#  0.7383333333333333,
#  0.7383333333333333,
#  0.7441666666666666,
#  0.7683333333333333,
#  0.77,
#  0.76875,
#  0.74375,
#  0.7582601422248451,
#  0.76875,
#  0.7554166666666666,
#  0.7695833333333333,
#  0.7620833333333333,
#  0.7829166666666667,
#  0.7695833333333333,
#  0.7900460058802194,
#  0.7579166666666667,
#  0.7804166666666666,
#  0.7879166666666667,
#  0.7749895441985838,
#  0.78625,
#  0.8020833333333334,
#  0.8004166666666667,
#  0.7866666666666666,
#  0.7820833333333334,
#  0.7929736511919699,
#  0.805,
#  0.7929166666666667]

# %%
plt.figure(figsize=(8,5))
plt.plot(range(1,51),results.history['acc'],c='g')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.title('Increasing Accuracy with Epochs');

# %% [markdown]
# ---
# ---
#
# ### Predicting on new Images

# %%
train_image_gen.class_indices
# Out:
# {'CAT': 0, 'DOG': 1}

# %% [markdown]
# Remember our model returns 0 for Cat and 1 for Dog

# %% [markdown]
# ---
# ---
#
# #### Changing Image format before prediction
# Since our model in trained on very specific image format(size,dimension and image array values) before predicting its class we have to convert our image in that format

# %%
from keras.preprocessing import image

def model_image_format(path):
    img = image.load_img(path,target_size=(150,150))
    img = image.img_to_array(img)
    img = np.expand_dims(img,axis=0)
    img = img/255
    return img

# %% [markdown]
# ---
#
# Checking model performance on some random images

# %%
path = 'CATS_DOGS/test/DOG/10193.jpg'
img = cv2.imread(path)
show(img)

# %% [markdown]
# * This image clearly have dogs , but its kind of hard to get as there is a lot of stuff in this image.
# * Lets see what the model thinks.

# %%
model_img = model_image_format(path)

# %%
model.predict_classes(model_img)
# Out:
# array([[1]])

# %% [markdown]
# As we know 1 means Dogs , hence it is right.

# %% [markdown]
# ---
# **Now lets check the probability of this Image having a dog according to model.**

# %%
model.predict_proba(model_img)
# Out:
# array([[0.6479505]], dtype=float32)

# %% [markdown]
# As we can see the probability is relatively low as the image contains a lot of things other then dog.

# %% [markdown]
# ---
# #### Lets try with a cat Image

# %%
path1 = 'CATS_DOGS/test/CAT/10498.jpg'
img = cv2.imread(path1)
show(img)

# %%
model_img2 = model_image_format(path1)

# %%
model.predict_classes(model_img2)
# Out:
# array([[0]])

# %% [markdown]
# Right Again : )

# %%
print(f'Probability of having cat in this image is : {model.predict_proba(model_img2)[0][0]}')
# Out:
# Probability of having cat in this image is : 0.36291810870170593

# %% [markdown]
# Which is surprising given that the cat is clearing visible in the image.

# %% [markdown]
# ---
# ---
# ---
#
# ## Note :

# %% [markdown]
# In this project the accuracy I'm Getting is around 80% but keep in mind that the accuracy can be increase furthur more by increasing the epochs during model training or by increasing layers in our model.

# %% [markdown]
# But that to come which a trade off , I'm running this code on a relatively older machine and our dataset contains 24,000+ images which in quite large. Because of that it takes me around **5 hr of training time**.

# %% [markdown]
# Final model has been saved in current directary under the name **cats_nd_dogs_50Epoch.h5**

# %% [markdown]
# #### ORIGINAL DATA SOURCE:
#
# https://www.microsoft.com/en-us/download/confirmation.aspx?id=54765

# %% [markdown]
# ---
#
# **Peace out**
